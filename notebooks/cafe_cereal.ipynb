# %%
cereals = pd.DataFrame([['Lucky Charms',21],
              ['Raisin Bran Crunch',27],
             ['Special K',5],
             ['Cheerios',2],
             ['Honey Nut Cheerios',17],
             ['Frosted Flakes',21],
              ['Cinnamon Toast Crunch',17]
             ],columns=['Cereal','Sugar Grams']).sort_values(by='Sugar Grams').reset_index(drop=True)

# %%
cereals
# Out:
#                   Cereal  Sugar Grams
# 0               Cheerios            2
# 1              Special K            5
# 2     Honey Nut Cheerios           17
# 3  Cinnamon Toast Crunch           17
# 4           Lucky Charms           21
# 5         Frosted Flakes           21
# 6     Raisin Bran Crunch           27

# %%
fig,ax = plt.subplots(figsize=(8,5))
fig.suptitle('Sugar Content of the Cereals at My Office Cafe',size=22)
bar = ax.barh(cereals.index,cereals['Sugar Grams'],facecolor='#C66634')
ax.tick_params(labelsize=16,labelcolor='#12019F')
ax.set_xlabel('Sugar (in g)',fontsize=16)
ax.set_yticks(cereals.index)
yticks = ax.set_yticklabels(cereals['Cereal'])
ax.text(-.1,-.3,'igotcharts.com, 2018',transform=ax.transAxes,fontsize=12)
os.chdir('//Users//alexanderpudlin//Documents//GitHub//charts_and_more_charts//outputs')
plt.savefig('Sugar_Content',dpi=80,bbox_inches = 'tight')
